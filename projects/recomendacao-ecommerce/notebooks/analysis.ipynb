# %% [markdown]
# # Recomendacao Ecommerce - Analysis Notes
#
# - Modelo selecionado: item_item_cosine
# - HitRate@10: 0.1333
# - MRR@10: 0.0531
# - Baseline HitRate@10: 0.1333
# - Modelo avancado HitRate@10: None
# - Usuarios avaliados: 450
# - Graficos em reports/: event_distribution.png, rank_coverage.png, top_recommended_items.png

# %%
from pathlib import Path
import json

project_root = Path('..')
metrics_path = project_root / 'models' / 'metrics.json'
if metrics_path.exists():
    metrics = json.loads(metrics_path.read_text(encoding='utf-8'))
    metrics
else:
    print('metrics.json nao encontrado')
